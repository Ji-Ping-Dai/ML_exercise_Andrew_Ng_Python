# %% [markdown]
# This is the first exercise of Andrew Ng's [Machine Learning](https://www.coursera.org/learn/machine-learning/home/welcome) written with Python3

# %% [markdown]
# ## 1. Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt 
plt.rc('text',usetex=True)
plt.rc('font',family='Times New Roman')
#read data
data = np.loadtxt('data/ex1data1.txt',delimiter=',')
X = data[:,0] #input
y = data[:,1] #output
#plot the dataset
fig = plt.figure(figsize=[7,5])
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Profit in \$10,000',size=20)
plt.xlabel('Population of City in 10,000s',size=20)
plt.scatter(X, y, color='r', marker='x')

# %%
plt.scatter?
